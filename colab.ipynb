# %% [markdown]
# # Maximum Accuracy Model Training Strategy
# ## Advanced Stacked Ensemble for Drug Category Classification
#
# **Objective:** Achieve maximum accuracy using state-of-the-art ensemble methods
#
# **Strategy:**
# - Layer 1: Multiple diverse base models (XGBoost, LightGBM, CatBoost, RF, ExtraTrees, NN)
# - Layer 2: Stacked meta-models
# - Bayesian hyperparameter optimization
# - 10-fold stratified cross-validation

# %%
# !git clone https://github.com/NuwanHapuarachchi/icds-2025-mini-hackathon.git
# Out:
# Cloning into 'icds-2025-mini-hackathon'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 110 (delta 17), reused 99 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (110/110), 9.00 MiB | 18.77 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !ls

#install catboost
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# optuna
# !pip install optuna
# Out:
# data			 README.md  TASK_COMPLETION_REPORT.md
# documentation		 reports    VERIFICATION_REPORT.md
# Notebook.ipynb		 scripts    verification_results.json
# PRE_MODELING_SUMMARY.md  Steps.md   visualizations
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (8.5.0)
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 31.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
#check cuda pytorch
import torch
print(torch.cuda.is_available())
#check xgboost cuda


# !nvidia-smi
# Out:
# True
# Sun Nov 16 07:58:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             10W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Core libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn preprocessing and metrics
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Base Models
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# Boosting models
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier

# Stacking
from sklearn.ensemble import StackingClassifier, VotingClassifier

# Hyperparameter optimization
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
try:
    import optuna
    OPTUNA_AVAILABLE = True
except:
    OPTUNA_AVAILABLE = False
    print("Optuna not available. Using GridSearchCV/RandomizedSearchCV only.")

# Utilities
import joblib
from datetime import datetime
import os

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("All libraries imported successfully!")
print(f"Optuna available: {OPTUNA_AVAILABLE}")
# Out:
# All libraries imported successfully!
# Optuna available: True

# %% [markdown]
# ## 2. Load Engineered Data

# %%
# Load engineered datasets
train_df = pd.read_csv('data/data_minihackathon_train_engineered.csv')
test_df = pd.read_csv('data/data_minihackathon_test_engineered.csv')

print(f"Train shape: {train_df.shape}")
print(f"Test shape: {test_df.shape}")
print(f"\nTarget distribution:")
print(train_df['drug_category'].value_counts())

# Separate features and target
X = train_df.drop(['drug_category', 'id'], axis=1, errors='ignore')
y = train_df['drug_category']
X_test = test_df.drop(['id'], axis=1, errors='ignore')
test_ids = test_df['id'] if 'id' in test_df.columns else np.arange(len(test_df))

# Encode target variable
le = LabelEncoder()
y_encoded = le.fit_transform(y)

print(f"\nFeatures shape: {X.shape}")
print(f"Test features shape: {X_test.shape}")
print(f"\nClass encoding: {dict(enumerate(le.classes_))}")
# Out:
# Train shape: (1500, 46)
# Test shape: (377, 45)
#
# Target distribution:
# drug_category
# Hallucinogens    691
# Stimulants       567
# Depressants      242
# Name: count, dtype: int64
#
# Features shape: (1500, 45)
# Test features shape: (377, 45)
#
# Class encoding: {0: 'Depressants', 1: 'Hallucinogens', 2: 'Stimulants'}

# %% [markdown]
# ## 3. Cross-Validation Setup

# %%
# Stratified K-Fold for cross-validation
N_FOLDS = 10
RANDOM_STATE = 42

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_STATE)

# Storage for model results
model_results = {}
oof_predictions = {}  # Out-of-fold predictions for stacking

print(f"Using {N_FOLDS}-fold stratified cross-validation")
print(f"Random state: {RANDOM_STATE}")
# Out:
# Using 10-fold stratified cross-validation
# Random state: 42

# %% [markdown]
# ## 4. Layer 1: Base Models
# ### 4.1 XGBoost with Bayesian Optimization

# %%
# %%time

print("\n" + "="*80)
print("Training XGBoost with Hyperparameter Tuning")
print("="*80)

if OPTUNA_AVAILABLE:
    # Bayesian optimization with Optuna
    def objective_xgb(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
            'max_depth': trial.suggest_int('max_depth', 3, 11),
            'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1, log=True),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
            'subsample': trial.suggest_float('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            'gamma': trial.suggest_float('gamma', 0, 0.3),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
            'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
            'random_state': RANDOM_STATE,
            'tree_method': 'hist',
            'eval_metric': 'mlogloss'
        }
        
        model = xgb.XGBClassifier(**params)
        scores = cross_val_score(model, X, y_encoded, cv=skf, scoring='accuracy', n_jobs=-1)
        return scores.mean()
    
    study_xgb = optuna.create_study(direction='maximize', study_name='xgboost')
    study_xgb.optimize(objective_xgb, n_trials=50, show_progress_bar=True)
    
    print(f"\nBest XGBoost accuracy: {study_xgb.best_value:.4f}")
    print(f"Best parameters: {study_xgb.best_params}")
    
    # Train final model with best parameters
    xgb_model = xgb.XGBClassifier(**study_xgb.best_params)
    
else:
    # Randomized search as fallback
    param_dist = {
        'n_estimators': [100, 300, 500, 700, 1000],
        'max_depth': [3, 5, 7, 9, 11],
        'learning_rate': [0.001, 0.01, 0.05, 0.1],
        'min_child_weight': [1, 3, 5, 7],
        'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
        'gamma': [0, 0.1, 0.2, 0.3],
        'reg_alpha': [0, 0.01, 0.1, 1],
        'reg_lambda': [0, 0.01, 0.1, 1]
    }
    
    xgb_base = xgb.XGBClassifier(random_state=RANDOM_STATE, tree_method='hist', eval_metric='mlogloss')
    random_search = RandomizedSearchCV(xgb_base, param_dist, n_iter=100, cv=5, 
                                      scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
    random_search.fit(X, y_encoded)
    
    print(f"\nBest XGBoost accuracy: {random_search.best_score_:.4f}")
    print(f"Best parameters: {random_search.best_params_}")
    
    xgb_model = random_search.best_estimator_

# Evaluate with cross-validation
cv_results = cross_validate(xgb_model, X, y_encoded, cv=skf, 
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['XGBoost'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': xgb_model
}

print(f"\nXGBoost CV Accuracy: {model_results['XGBoost']['cv_accuracy']:.4f} ± {model_results['XGBoost']['cv_std']:.4f}")
print(f"XGBoost F1-Macro: {model_results['XGBoost']['f1_macro']:.4f}")
# Out:
# [I 2025-11-16 07:59:08,999] A new study created in memory with name: xgboost
# ================================================================================
# Training XGBoost with Hyperparameter Tuning
# ================================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-16 07:59:45,425] Trial 0 finished with value: 0.712 and parameters: {'n_estimators': 356, 'max_depth': 8, 'learning_rate': 0.026780085943140446, 'min_child_weight': 2, 'subsample': 0.8044018934461487, 'colsample_bytree': 0.7938482776001846, 'gamma': 0.2173246100820851, 'reg_alpha': 0.36186442575410593, 'reg_lambda': 0.5664526979505914}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:00:57,523] Trial 1 finished with value: 0.7100000000000001 and parameters: {'n_estimators': 573, 'max_depth': 6, 'learning_rate': 0.00450675521490974, 'min_child_weight': 1, 'subsample': 0.7502678162720894, 'colsample_bytree': 0.9884205099133019, 'gamma': 0.04045491803659055, 'reg_alpha': 0.1770509226761039, 'reg_lambda': 0.6093682600756556}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:02:39,648] Trial 2 finished with value: 0.712 and parameters: {'n_estimators': 735, 'max_depth': 8, 'learning_rate': 0.002656503479703631, 'min_child_weight': 1, 'subsample': 0.7236644713115774, 'colsample_bytree': 0.6110309370771076, 'gamma': 0.16095699167134747, 'reg_alpha': 0.4906166687379736, 'reg_lambda': 0.22715426035058428}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:02:49,248] Trial 3 finished with value: 0.7046666666666667 and parameters: {'n_estimators': 113, 'max_depth': 10, 'learning_rate': 0.07610375140080027, 'min_child_weight': 3, 'subsample': 0.6669502192215421, 'colsample_bytree': 0.6334150847618665, 'gamma': 0.18455557175582088, 'reg_alpha': 0.6508553236080526, 'reg_lambda': 0.60254320321913}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:03:05,225] Trial 4 finished with value: 0.6980000000000001 and parameters: {'n_estimators': 717, 'max_depth': 5, 'learning_rate': 0.06060100683195129, 'min_child_weight': 3, 'subsample': 0.8647982035547419, 'colsample_bytree': 0.7598996271817574, 'gamma': 0.2980468573212254, 'reg_alpha': 0.45022120189725456, 'reg_lambda': 0.7166304817783784}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:06:09,631] Trial 5 finished with value: 0.7093333333333333 and parameters: {'n_estimators': 939, 'max_depth': 11, 'learning_rate': 0.003628732578225448, 'min_child_weight': 2, 'subsample': 0.7907846556487939, 'colsample_bytree': 0.9319561920219919, 'gamma': 0.03775690879051129, 'reg_alpha': 0.3428974970781197, 'reg_lambda': 0.9021084022956702}. Best is trial 0 with value: 0.712.
# [I 2025-11-16 08:06:55,134] Trial 6 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 677, 'max_depth': 5, 'learning_rate': 0.007329236387668063, 'min_child_weight': 1, 'subsample': 0.9563396241839881, 'colsample_bytree': 0.6906075768098812, 'gamma': 0.21556725683605113, 'reg_alpha': 0.5337287220291187, 'reg_lambda': 0.4496509131574117}. Best is trial 6 with value: 0.7126666666666667.
# [I 2025-11-16 08:07:01,396] Trial 7 finished with value: 0.708 and parameters: {'n_estimators': 127, 'max_depth': 6, 'learning_rate': 0.02230666979938029, 'min_child_weight': 7, 'subsample': 0.8508328692212694, 'colsample_bytree': 0.6212017433779389, 'gamma': 0.26735813805138975, 'reg_alpha': 0.6991867494264672, 'reg_lambda': 0.10302511205360776}. Best is trial 6 with value: 0.7126666666666667.
# [I 2025-11-16 08:08:23,198] Trial 8 finished with value: 0.7093333333333333 and parameters: {'n_estimators': 703, 'max_depth': 10, 'learning_rate': 0.0013370453510657165, 'min_child_weight': 4, 'subsample': 0.9931418894779271, 'colsample_bytree': 0.6770984551442565, 'gamma': 0.041973395637476076, 'reg_alpha': 0.9014361787044737, 'reg_lambda': 0.9106925329693545}. Best is trial 6 with value: 0.7126666666666667.
# [I 2025-11-16 08:08:31,667] Trial 9 finished with value: 0.7133333333333334 and parameters: {'n_estimators': 142, 'max_depth': 6, 'learning_rate': 0.030419026725571164, 'min_child_weight': 5, 'subsample': 0.780123450693399, 'colsample_bytree': 0.6301929039677886, 'gamma': 0.10891493226705858, 'reg_alpha': 0.18477931689555338, 'reg_lambda': 0.9904427442382102}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:08:40,712] Trial 10 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 359, 'max_depth': 3, 'learning_rate': 0.021495364388178975, 'min_child_weight': 6, 'subsample': 0.600941687115398, 'colsample_bytree': 0.8691776550871317, 'gamma': 0.10592585648708398, 'reg_alpha': 0.03744001352844761, 'reg_lambda': 0.9924933530774346}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:08:56,555] Trial 11 finished with value: 0.7093333333333334 and parameters: {'n_estimators': 452, 'max_depth': 4, 'learning_rate': 0.009289348396770118, 'min_child_weight': 5, 'subsample': 0.9917908089056405, 'colsample_bytree': 0.7066464080352404, 'gamma': 0.109818769714283, 'reg_alpha': 0.22084278705484744, 'reg_lambda': 0.3517175497700562}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:10:01,284] Trial 12 finished with value: 0.7086666666666666 and parameters: {'n_estimators': 968, 'max_depth': 7, 'learning_rate': 0.009091864342891378, 'min_child_weight': 5, 'subsample': 0.9141646151152849, 'colsample_bytree': 0.7291748200370595, 'gamma': 0.1106495725701666, 'reg_alpha': 0.6647602040921432, 'reg_lambda': 0.38161854285655206}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:10:09,901] Trial 13 finished with value: 0.71 and parameters: {'n_estimators': 279, 'max_depth': 4, 'learning_rate': 0.035550860006940424, 'min_child_weight': 5, 'subsample': 0.9216054951458936, 'colsample_bytree': 0.6756001406935443, 'gamma': 0.2200274668044057, 'reg_alpha': 0.024306271230872006, 'reg_lambda': 0.42693862846956077}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:10:39,749] Trial 14 finished with value: 0.7086666666666666 and parameters: {'n_estimators': 569, 'max_depth': 6, 'learning_rate': 0.014547843810787504, 'min_child_weight': 7, 'subsample': 0.7011986153708372, 'colsample_bytree': 0.8564432018433502, 'gamma': 0.22993117206988506, 'reg_alpha': 0.8433062741232198, 'reg_lambda': 0.7631269473647093}. Best is trial 9 with value: 0.7133333333333334.
# [I 2025-11-16 08:10:57,683] Trial 15 finished with value: 0.7173333333333333 and parameters: {'n_estimators': 820, 'max_depth': 3, 'learning_rate': 0.006437432946166005, 'min_child_weight': 4, 'subsample': 0.9177922338002047, 'colsample_bytree': 0.6775063720936535, 'gamma': 0.14461605095730612, 'reg_alpha': 0.20249998164471683, 'reg_lambda': 0.2515308258544451}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:11:15,691] Trial 16 finished with value: 0.6893333333333334 and parameters: {'n_estimators': 807, 'max_depth': 3, 'learning_rate': 0.05254486934674156, 'min_child_weight': 4, 'subsample': 0.8443304669300313, 'colsample_bytree': 0.756591289702979, 'gamma': 0.08227010450510464, 'reg_alpha': 0.16692556609210213, 'reg_lambda': 0.08213855157854105}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:12:30,326] Trial 18 finished with value: 0.698 and parameters: {'n_estimators': 216, 'max_depth': 4, 'learning_rate': 0.005930300196975401, 'min_child_weight': 3, 'subsample': 0.8976290703962223, 'colsample_bytree': 0.8198408704733758, 'gamma': 0.0747345964239635, 'reg_alpha': 0.11122379243494962, 'reg_lambda': 0.27246842536943694}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:12:40,316] Trial 19 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 464, 'max_depth': 3, 'learning_rate': 0.016268872078746104, 'min_child_weight': 6, 'subsample': 0.6634744203938122, 'colsample_bytree': 0.64636192387433, 'gamma': 0.1418356759597828, 'reg_alpha': 0.36479423564807073, 'reg_lambda': 0.7717346289088791}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:12:51,869] Trial 20 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 511, 'max_depth': 3, 'learning_rate': 0.012976765116483898, 'min_child_weight': 6, 'subsample': 0.6703877788670508, 'colsample_bytree': 0.7308290617253089, 'gamma': 0.14966724638774181, 'reg_alpha': 0.3925541495798791, 'reg_lambda': 0.7462072219729073}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:13:02,825] Trial 21 finished with value: 0.716 and parameters: {'n_estimators': 480, 'max_depth': 3, 'learning_rate': 0.014409914634826671, 'min_child_weight': 6, 'subsample': 0.6345869310434177, 'colsample_bytree': 0.740674294937382, 'gamma': 0.15077792276583543, 'reg_alpha': 0.4063148701929505, 'reg_lambda': 0.7649129240207254}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:13:11,624] Trial 22 finished with value: 0.7166666666666666 and parameters: {'n_estimators': 434, 'max_depth': 3, 'learning_rate': 0.016206666065160767, 'min_child_weight': 6, 'subsample': 0.6077830608449114, 'colsample_bytree': 0.656557229300476, 'gamma': 0.17865289800841577, 'reg_alpha': 0.2781845314124298, 'reg_lambda': 0.8201116194589646}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:13:32,245] Trial 23 finished with value: 0.71 and parameters: {'n_estimators': 610, 'max_depth': 4, 'learning_rate': 0.005250821576796476, 'min_child_weight': 7, 'subsample': 0.6109907548950333, 'colsample_bytree': 0.7836531571033122, 'gamma': 0.1825710543903581, 'reg_alpha': 0.2638675318050093, 'reg_lambda': 0.8340726703026955}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:13:53,701] Trial 24 finished with value: 0.71 and parameters: {'n_estimators': 396, 'max_depth': 5, 'learning_rate': 0.002735360332553496, 'min_child_weight': 4, 'subsample': 0.6555917473716741, 'colsample_bytree': 0.7173244805985333, 'gamma': 0.18646174719519215, 'reg_alpha': 0.5328149758657268, 'reg_lambda': 0.6564973502502872}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:14:06,443] Trial 25 finished with value: 0.7166666666666666 and parameters: {'n_estimators': 633, 'max_depth': 3, 'learning_rate': 0.01216494077914174, 'min_child_weight': 4, 'subsample': 0.631340097783181, 'colsample_bytree': 0.6023093792037371, 'gamma': 0.002316574166965485, 'reg_alpha': 0.102587357217029, 'reg_lambda': 0.5379971279963278}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:14:31,784] Trial 26 finished with value: 0.71 and parameters: {'n_estimators': 856, 'max_depth': 4, 'learning_rate': 0.011042182628777335, 'min_child_weight': 4, 'subsample': 0.6283509577295404, 'colsample_bytree': 0.6588019334828911, 'gamma': 0.018301933157040123, 'reg_alpha': 0.10233726838732747, 'reg_lambda': 0.5299253455898143}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:14:51,963] Trial 27 finished with value: 0.7 and parameters: {'n_estimators': 639, 'max_depth': 5, 'learning_rate': 0.04172270406317039, 'min_child_weight': 3, 'subsample': 0.7138814591604012, 'colsample_bytree': 0.6477849915875517, 'gamma': 0.2517695815138503, 'reg_alpha': 0.09411624972811909, 'reg_lambda': 0.30231683294127276}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:15:08,305] Trial 28 finished with value: 0.7153333333333333 and parameters: {'n_estimators': 791, 'max_depth': 3, 'learning_rate': 0.0075212735300027415, 'min_child_weight': 4, 'subsample': 0.6945123135647909, 'colsample_bytree': 0.6206729467085406, 'gamma': 0.01629916890775153, 'reg_alpha': 0.264178969395276, 'reg_lambda': 0.027049292825384763}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:16:01,089] Trial 29 finished with value: 0.7053333333333333 and parameters: {'n_estimators': 880, 'max_depth': 7, 'learning_rate': 0.019993482936594018, 'min_child_weight': 2, 'subsample': 0.7422306025231687, 'colsample_bytree': 0.6003860809720697, 'gamma': 0.0740874551940706, 'reg_alpha': 0.31819763627695885, 'reg_lambda': 0.15260403757724283}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:16:28,257] Trial 30 finished with value: 0.7106666666666667 and parameters: {'n_estimators': 765, 'max_depth': 4, 'learning_rate': 0.003578146294449873, 'min_child_weight': 5, 'subsample': 0.8208020806234826, 'colsample_bytree': 0.702935227588382, 'gamma': 0.20284826141986348, 'reg_alpha': 0.08050757598679689, 'reg_lambda': 0.5041034385660405}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:16:38,621] Trial 31 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 498, 'max_depth': 3, 'learning_rate': 0.016729728825769914, 'min_child_weight': 6, 'subsample': 0.6438947853194021, 'colsample_bytree': 0.7491859067316822, 'gamma': 0.13115768271224043, 'reg_alpha': 0.4053619694029848, 'reg_lambda': 0.6610039191209247}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:16:48,677] Trial 32 finished with value: 0.7166666666666666 and parameters: {'n_estimators': 404, 'max_depth': 3, 'learning_rate': 0.01103143820918439, 'min_child_weight': 5, 'subsample': 0.6294601084233398, 'colsample_bytree': 0.7925560373544696, 'gamma': 0.17720870809836356, 'reg_alpha': 0.2180058862904774, 'reg_lambda': 0.8380290129312733}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:16:59,943] Trial 33 finished with value: 0.7086666666666668 and parameters: {'n_estimators': 285, 'max_depth': 4, 'learning_rate': 0.0068456944831953885, 'min_child_weight': 5, 'subsample': 0.6200488633052806, 'colsample_bytree': 0.812856202672687, 'gamma': 0.17082986592928057, 'reg_alpha': 0.18527006224390313, 'reg_lambda': 0.8921663643157804}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:17:11,281] Trial 34 finished with value: 0.7093333333333334 and parameters: {'n_estimators': 384, 'max_depth': 3, 'learning_rate': 0.01049898414401546, 'min_child_weight': 4, 'subsample': 0.6768306927892026, 'colsample_bytree': 0.9878228751853363, 'gamma': 0.2017454446872247, 'reg_alpha': 0.14656319858239322, 'reg_lambda': 0.8428928022438915}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:17:33,388] Trial 35 finished with value: 0.7033333333333334 and parameters: {'n_estimators': 547, 'max_depth': 5, 'learning_rate': 0.029118131254491232, 'min_child_weight': 3, 'subsample': 0.7420913225081273, 'colsample_bytree': 0.601556059789067, 'gamma': 0.2375498364632927, 'reg_alpha': 0.23657591116732613, 'reg_lambda': 0.575956308055795}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:18:09,338] Trial 36 finished with value: 0.7046666666666667 and parameters: {'n_estimators': 423, 'max_depth': 9, 'learning_rate': 0.004217561379806929, 'min_child_weight': 5, 'subsample': 0.6007450656239416, 'colsample_bytree': 0.8486726725357692, 'gamma': 0.28364790025124265, 'reg_alpha': 0.30806799261634443, 'reg_lambda': 0.6651521001920041}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:18:20,782] Trial 37 finished with value: 0.6960000000000001 and parameters: {'n_estimators': 298, 'max_depth': 4, 'learning_rate': 0.09578741647939011, 'min_child_weight': 3, 'subsample': 0.6888751009012731, 'colsample_bytree': 0.9046138277768438, 'gamma': 0.170301906089178, 'reg_alpha': 0.4636850139232291, 'reg_lambda': 0.44558782892359383}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:18:37,344] Trial 38 finished with value: 0.7166666666666666 and parameters: {'n_estimators': 674, 'max_depth': 3, 'learning_rate': 0.008624730281590933, 'min_child_weight': 5, 'subsample': 0.6480318253314187, 'colsample_bytree': 0.7810187331289246, 'gamma': 0.0016407375153367479, 'reg_alpha': 0.008360379693512207, 'reg_lambda': 0.8210812214103698}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:19:25,399] Trial 39 finished with value: 0.7146666666666666 and parameters: {'n_estimators': 903, 'max_depth': 5, 'learning_rate': 0.011710236245588123, 'min_child_weight': 2, 'subsample': 0.8811613340307235, 'colsample_bytree': 0.6907189832138487, 'gamma': 0.05959353692852422, 'reg_alpha': 0.2276397680904989, 'reg_lambda': 0.7015857258296452}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:19:58,917] Trial 40 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 999, 'max_depth': 4, 'learning_rate': 0.0056040867703543214, 'min_child_weight': 4, 'subsample': 0.9503752815051982, 'colsample_bytree': 0.638080635019779, 'gamma': 0.12857582858924718, 'reg_alpha': 0.587512425331939, 'reg_lambda': 0.9377483901158212}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:20:13,992] Trial 41 finished with value: 0.7139999999999999 and parameters: {'n_estimators': 645, 'max_depth': 3, 'learning_rate': 0.008223396824411236, 'min_child_weight': 5, 'subsample': 0.6429404700156922, 'colsample_bytree': 0.7947516258264065, 'gamma': 0.004748450452831241, 'reg_alpha': 0.0007613821785917296, 'reg_lambda': 0.7891399348663246}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:20:30,499] Trial 42 finished with value: 0.7106666666666666 and parameters: {'n_estimators': 747, 'max_depth': 3, 'learning_rate': 0.018402492333331213, 'min_child_weight': 5, 'subsample': 0.6267891542641597, 'colsample_bytree': 0.7789332042405938, 'gamma': 0.03081176706194918, 'reg_alpha': 0.05959131168098904, 'reg_lambda': 0.8313956336186705}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:20:45,952] Trial 43 finished with value: 0.7013333333333334 and parameters: {'n_estimators': 695, 'max_depth': 3, 'learning_rate': 0.02606505396301555, 'min_child_weight': 6, 'subsample': 0.6474854996344014, 'colsample_bytree': 0.8317462070658088, 'gamma': 0.05353294553613658, 'reg_alpha': 0.13229189996048218, 'reg_lambda': 0.861917797606213}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:21:51,847] Trial 44 finished with value: 0.708 and parameters: {'n_estimators': 537, 'max_depth': 11, 'learning_rate': 0.006677542051438654, 'min_child_weight': 4, 'subsample': 0.7168064785224046, 'colsample_bytree': 0.9087958880670269, 'gamma': 0.000631703879867886, 'reg_alpha': 0.20292756520284627, 'reg_lambda': 0.9421156789681092}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:22:12,940] Trial 45 finished with value: 0.716 and parameters: {'n_estimators': 605, 'max_depth': 4, 'learning_rate': 0.009513112195980163, 'min_child_weight': 5, 'subsample': 0.8181993318956741, 'colsample_bytree': 0.7700946317188899, 'gamma': 0.19841073662946654, 'reg_alpha': 0.051286866304954826, 'reg_lambda': 0.5930000992640437}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:22:27,874] Trial 46 finished with value: 0.7086666666666667 and parameters: {'n_estimators': 650, 'max_depth': 3, 'learning_rate': 0.004893275518926821, 'min_child_weight': 4, 'subsample': 0.6172304135231153, 'colsample_bytree': 0.6902395046805386, 'gamma': 0.026023110802035163, 'reg_alpha': 0.1516370318586129, 'reg_lambda': 0.8054401169590464}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:22:41,598] Trial 47 finished with value: 0.7153333333333333 and parameters: {'n_estimators': 318, 'max_depth': 5, 'learning_rate': 0.012899051400389216, 'min_child_weight': 5, 'subsample': 0.7646206411916631, 'colsample_bytree': 0.6245957370501217, 'gamma': 0.0915761518474524, 'reg_alpha': 0.012886725852188962, 'reg_lambda': 0.7150764572646435}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:23:03,882] Trial 48 finished with value: 0.7 and parameters: {'n_estimators': 591, 'max_depth': 6, 'learning_rate': 0.024669478693008156, 'min_child_weight': 7, 'subsample': 0.601150084092053, 'colsample_bytree': 0.6593718886634664, 'gamma': 0.03986083242249658, 'reg_alpha': 0.06617997744313624, 'reg_lambda': 0.3923454788724157}. Best is trial 15 with value: 0.7173333333333333.
# [I 2025-11-16 08:23:19,465] Trial 49 finished with value: 0.7060000000000001 and parameters: {'n_estimators': 442, 'max_depth': 4, 'learning_rate': 0.004001099514608238, 'min_child_weight': 4, 'subsample': 0.6817626933835885, 'colsample_bytree': 0.6815457112783946, 'gamma': 0.16908799296999594, 'reg_alpha': 0.7871701917675396, 'reg_lambda': 0.6322620057445605}. Best is trial 15 with value: 0.7173333333333333.
#
# Best XGBoost accuracy: 0.7173
# Best parameters: {'n_estimators': 820, 'max_depth': 3, 'learning_rate': 0.006437432946166005, 'min_child_weight': 4, 'subsample': 0.9177922338002047, 'colsample_bytree': 0.6775063720936535, 'gamma': 0.14461605095730612, 'reg_alpha': 0.20249998164471683, 'reg_lambda': 0.2515308258544451}
#
# XGBoost CV Accuracy: 0.7167 ± 0.0226
# XGBoost F1-Macro: 0.5279
# CPU times: user 45.5 s, sys: 1.29 s, total: 46.8 s
# Wall time: 24min 32s

# %% [markdown]
# ### 4.2 LightGBM with Hyperparameter Tuning

# %%
# %%time

print("\n" + "="*80)
print("Training LightGBM with Hyperparameter Tuning")
print("="*80)

if OPTUNA_AVAILABLE:
    def objective_lgb(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
            'num_leaves': trial.suggest_int('num_leaves', 15, 255),
            'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1, log=True),
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 50),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'lambda_l1': trial.suggest_float('lambda_l1', 0, 10),
            'lambda_l2': trial.suggest_float('lambda_l2', 0, 10),
            'random_state': RANDOM_STATE,
            'verbose': -1
        }
        
        model = lgb.LGBMClassifier(**params)
        scores = cross_val_score(model, X, y_encoded, cv=skf, scoring='accuracy', n_jobs=-1)
        return scores.mean()
    
    study_lgb = optuna.create_study(direction='maximize', study_name='lightgbm')
    study_lgb.optimize(objective_lgb, n_trials=100, show_progress_bar=True)
    
    print(f"\nBest LightGBM accuracy: {study_lgb.best_value:.4f}")
    print(f"Best parameters: {study_lgb.best_params}")
    
    lgb_model = lgb.LGBMClassifier(**study_lgb.best_params)
    
else:
    param_dist = {
        'n_estimators': [100, 300, 500, 700, 1000],
        'num_leaves': [15, 31, 63, 127, 255],
        'learning_rate': [0.001, 0.01, 0.05, 0.1],
        'min_data_in_leaf': [10, 20, 30, 50],
        'feature_fraction': [0.6, 0.7, 0.8, 0.9, 1.0],
        'bagging_fraction': [0.6, 0.7, 0.8, 0.9, 1.0],
        'lambda_l1': [0, 0.1, 1, 10],
        'lambda_l2': [0, 0.1, 1, 10]
    }
    
    lgb_base = lgb.LGBMClassifier(random_state=RANDOM_STATE, verbose=-1)
    random_search = RandomizedSearchCV(lgb_base, param_dist, n_iter=100, cv=5,
                                      scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
    random_search.fit(X, y_encoded)
    
    print(f"\nBest LightGBM accuracy: {random_search.best_score_:.4f}")
    print(f"Best parameters: {random_search.best_params_}")
    
    lgb_model = random_search.best_estimator_

cv_results = cross_validate(lgb_model, X, y_encoded, cv=skf,
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['LightGBM'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': lgb_model
}

print(f"\nLightGBM CV Accuracy: {model_results['LightGBM']['cv_accuracy']:.4f} ± {model_results['LightGBM']['cv_std']:.4f}")
print(f"LightGBM F1-Macro: {model_results['LightGBM']['f1_macro']:.4f}")
# Out:
# [I 2025-11-16 08:26:48,471] A new study created in memory with name: lightgbm
# ================================================================================
# Training LightGBM with Hyperparameter Tuning
# ================================================================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-16 08:26:59,829] Trial 0 finished with value: 0.6953333333333334 and parameters: {'n_estimators': 398, 'num_leaves': 33, 'learning_rate': 0.0014539031802999567, 'min_data_in_leaf': 38, 'feature_fraction': 0.8483417691246561, 'bagging_fraction': 0.7086446513390413, 'bagging_freq': 6, 'lambda_l1': 3.096712210156005, 'lambda_l2': 6.831267645004892}. Best is trial 0 with value: 0.6953333333333334.
# [I 2025-11-16 08:27:25,665] Trial 1 finished with value: 0.7006666666666667 and parameters: {'n_estimators': 703, 'num_leaves': 131, 'learning_rate': 0.03928178604288427, 'min_data_in_leaf': 10, 'feature_fraction': 0.9262606261184344, 'bagging_fraction': 0.8843824147434094, 'bagging_freq': 2, 'lambda_l1': 3.617745458172056, 'lambda_l2': 9.3468514839129}. Best is trial 1 with value: 0.7006666666666667.
# [I 2025-11-16 08:27:41,547] Trial 2 finished with value: 0.7113333333333334 and parameters: {'n_estimators': 969, 'num_leaves': 90, 'learning_rate': 0.024520793273393498, 'min_data_in_leaf': 32, 'feature_fraction': 0.9942547855591016, 'bagging_fraction': 0.7760948718828037, 'bagging_freq': 3, 'lambda_l1': 9.341246919742504, 'lambda_l2': 9.77254280001291}. Best is trial 2 with value: 0.7113333333333334.
# [I 2025-11-16 08:28:04,558] Trial 3 finished with value: 0.7073333333333334 and parameters: {'n_estimators': 897, 'num_leaves': 241, 'learning_rate': 0.0016056880006706303, 'min_data_in_leaf': 32, 'feature_fraction': 0.6574632804111168, 'bagging_fraction': 0.9622186151835014, 'bagging_freq': 1, 'lambda_l1': 2.538108214153667, 'lambda_l2': 7.808055129827115}. Best is trial 2 with value: 0.7113333333333334.
# [I 2025-11-16 08:28:07,480] Trial 4 finished with value: 0.6713333333333333 and parameters: {'n_estimators': 146, 'num_leaves': 165, 'learning_rate': 0.002181448149520173, 'min_data_in_leaf': 37, 'feature_fraction': 0.7849407141588431, 'bagging_fraction': 0.8796074320777588, 'bagging_freq': 2, 'lambda_l1': 8.929387829992548, 'lambda_l2': 0.426870911741114}. Best is trial 2 with value: 0.7113333333333334.
# [I 2025-11-16 08:28:31,808] Trial 5 finished with value: 0.7006666666666667 and parameters: {'n_estimators': 382, 'num_leaves': 167, 'learning_rate': 0.07139726207765494, 'min_data_in_leaf': 11, 'feature_fraction': 0.8697256411760845, 'bagging_fraction': 0.916571436538177, 'bagging_freq': 2, 'lambda_l1': 0.631928990957914, 'lambda_l2': 6.008988169115328}. Best is trial 2 with value: 0.7113333333333334.
# [I 2025-11-16 08:28:41,123] Trial 6 finished with value: 0.714 and parameters: {'n_estimators': 452, 'num_leaves': 248, 'learning_rate': 0.013185594441573823, 'min_data_in_leaf': 38, 'feature_fraction': 0.7504747473774285, 'bagging_fraction': 0.695379512699251, 'bagging_freq': 7, 'lambda_l1': 5.748435178317211, 'lambda_l2': 8.393263503161757}. Best is trial 6 with value: 0.714.
# [I 2025-11-16 08:28:47,156] Trial 7 finished with value: 0.6806666666666666 and parameters: {'n_estimators': 358, 'num_leaves': 185, 'learning_rate': 0.0010749498782120562, 'min_data_in_leaf': 38, 'feature_fraction': 0.7601698036427234, 'bagging_fraction': 0.6435868892661746, 'bagging_freq': 1, 'lambda_l1': 6.247115297389706, 'lambda_l2': 1.415507388083057}. Best is trial 6 with value: 0.714.
# [I 2025-11-16 08:28:58,670] Trial 8 finished with value: 0.6893333333333334 and parameters: {'n_estimators': 854, 'num_leaves': 165, 'learning_rate': 0.0924213901421227, 'min_data_in_leaf': 46, 'feature_fraction': 0.7257878843262314, 'bagging_fraction': 0.9182206009397441, 'bagging_freq': 5, 'lambda_l1': 3.558558167000011, 'lambda_l2': 7.018856733260682}. Best is trial 6 with value: 0.714.
# [I 2025-11-16 08:29:32,350] Trial 9 finished with value: 0.7093333333333333 and parameters: {'n_estimators': 883, 'num_leaves': 140, 'learning_rate': 0.0023063361162824025, 'min_data_in_leaf': 18, 'feature_fraction': 0.8418000230015127, 'bagging_fraction': 0.7481632051886128, 'bagging_freq': 5, 'lambda_l1': 0.7226954116063677, 'lambda_l2': 9.408056323665166}. Best is trial 6 with value: 0.714.
# [I 2025-11-16 08:29:40,574] Trial 10 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 587, 'num_leaves': 245, 'learning_rate': 0.006788589017258883, 'min_data_in_leaf': 48, 'feature_fraction': 0.6008418370101053, 'bagging_fraction': 0.6015248024266855, 'bagging_freq': 7, 'lambda_l1': 6.544234463218482, 'lambda_l2': 3.3135206375813393}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:29:47,902] Trial 11 finished with value: 0.7133333333333333 and parameters: {'n_estimators': 599, 'num_leaves': 252, 'learning_rate': 0.007513559780469681, 'min_data_in_leaf': 50, 'feature_fraction': 0.6074378677425204, 'bagging_fraction': 0.6055842836000972, 'bagging_freq': 7, 'lambda_l1': 7.194820077955814, 'lambda_l2': 3.454966384667174}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:29:57,612] Trial 12 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 552, 'num_leaves': 217, 'learning_rate': 0.01045869053978352, 'min_data_in_leaf': 45, 'feature_fraction': 0.7003993066277878, 'bagging_fraction': 0.675493908586611, 'bagging_freq': 7, 'lambda_l1': 6.045072882224255, 'lambda_l2': 3.8301292566159004}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:07,743] Trial 13 finished with value: 0.7126666666666666 and parameters: {'n_estimators': 679, 'num_leaves': 207, 'learning_rate': 0.0053190404870764214, 'min_data_in_leaf': 45, 'feature_fraction': 0.6758071773810481, 'bagging_fraction': 0.6453244611845873, 'bagging_freq': 6, 'lambda_l1': 7.879314613896612, 'lambda_l2': 3.7776322541129383}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:16,983] Trial 14 finished with value: 0.7086666666666667 and parameters: {'n_estimators': 534, 'num_leaves': 219, 'learning_rate': 0.003999695662398476, 'min_data_in_leaf': 24, 'feature_fraction': 0.6021704605609889, 'bagging_fraction': 0.609499262836629, 'bagging_freq': 7, 'lambda_l1': 4.8078044317681226, 'lambda_l2': 3.2256893368078012}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:21,732] Trial 15 finished with value: 0.7113333333333334 and parameters: {'n_estimators': 221, 'num_leaves': 211, 'learning_rate': 0.014351969183764243, 'min_data_in_leaf': 44, 'feature_fraction': 0.6842062504013235, 'bagging_fraction': 0.8198724931368755, 'bagging_freq': 5, 'lambda_l1': 7.098558459102144, 'lambda_l2': 4.397603854142164}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:33,683] Trial 16 finished with value: 0.7100000000000001 and parameters: {'n_estimators': 713, 'num_leaves': 102, 'learning_rate': 0.02161548416660456, 'min_data_in_leaf': 50, 'feature_fraction': 0.6582194231390853, 'bagging_fraction': 0.6826010744970381, 'bagging_freq': 6, 'lambda_l1': 4.799095515421127, 'lambda_l2': 1.8098931886607863}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:42,161] Trial 17 finished with value: 0.7113333333333334 and parameters: {'n_estimators': 545, 'num_leaves': 216, 'learning_rate': 0.007031357187404346, 'min_data_in_leaf': 42, 'feature_fraction': 0.7179918674997059, 'bagging_fraction': 0.7361258371482375, 'bagging_freq': 4, 'lambda_l1': 8.109651514147817, 'lambda_l2': 5.077898118328594}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:47,455] Trial 18 finished with value: 0.7013333333333334 and parameters: {'n_estimators': 259, 'num_leaves': 15, 'learning_rate': 0.0038859753275970093, 'min_data_in_leaf': 26, 'feature_fraction': 0.6200697907159423, 'bagging_fraction': 0.6598400955631191, 'bagging_freq': 4, 'lambda_l1': 5.91004970960962, 'lambda_l2': 2.32189798065263}. Best is trial 10 with value: 0.7146666666666667.
# [I 2025-11-16 08:30:58,588] Trial 19 finished with value: 0.7166666666666667 and parameters: {'n_estimators': 788, 'num_leaves': 199, 'learning_rate': 0.010679263888305963, 'min_data_in_leaf': 50, 'feature_fraction': 0.7153630023730766, 'bagging_fraction': 0.8252719874189145, 'bagging_freq': 6, 'lambda_l1': 9.817390671451886, 'lambda_l2': 5.517380064096044}. Best is trial 19 with value: 0.7166666666666667.
# [I 2025-11-16 08:31:07,785] Trial 20 finished with value: 0.718 and parameters: {'n_estimators': 794, 'num_leaves': 182, 'learning_rate': 0.025821457156450945, 'min_data_in_leaf': 50, 'feature_fraction': 0.8102324061976697, 'bagging_fraction': 0.8207221322102137, 'bagging_freq': 6, 'lambda_l1': 9.775815225590222, 'lambda_l2': 5.079487449573362}. Best is trial 20 with value: 0.718.
# [I 2025-11-16 08:31:17,494] Trial 21 finished with value: 0.7193333333333334 and parameters: {'n_estimators': 815, 'num_leaves': 187, 'learning_rate': 0.03216909943461598, 'min_data_in_leaf': 50, 'feature_fraction': 0.8023597830283957, 'bagging_fraction': 0.8268688334670098, 'bagging_freq': 6, 'lambda_l1': 9.926271993413742, 'lambda_l2': 5.373437805934451}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:31:26,240] Trial 22 finished with value: 0.716 and parameters: {'n_estimators': 784, 'num_leaves': 191, 'learning_rate': 0.04227580699358584, 'min_data_in_leaf': 41, 'feature_fraction': 0.8096913235263303, 'bagging_fraction': 0.829014010227727, 'bagging_freq': 6, 'lambda_l1': 9.922062915399408, 'lambda_l2': 5.515923345612124}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:31:36,723] Trial 23 finished with value: 0.7113333333333334 and parameters: {'n_estimators': 763, 'num_leaves': 139, 'learning_rate': 0.021030034246334716, 'min_data_in_leaf': 50, 'feature_fraction': 0.9019916938369699, 'bagging_fraction': 0.8512443565739616, 'bagging_freq': 5, 'lambda_l1': 9.884830530491408, 'lambda_l2': 6.194690204301878}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:31:47,045] Trial 24 finished with value: 0.7106666666666667 and parameters: {'n_estimators': 986, 'num_leaves': 189, 'learning_rate': 0.04066808499354311, 'min_data_in_leaf': 41, 'feature_fraction': 0.797035278077639, 'bagging_fraction': 0.7877316310368595, 'bagging_freq': 6, 'lambda_l1': 8.629385996726194, 'lambda_l2': 4.889747834026352}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:31:58,910] Trial 25 finished with value: 0.716 and parameters: {'n_estimators': 814, 'num_leaves': 121, 'learning_rate': 0.030159791465513744, 'min_data_in_leaf': 48, 'feature_fraction': 0.8225449931998928, 'bagging_fraction': 0.8496697926215967, 'bagging_freq': 5, 'lambda_l1': 7.977195533201272, 'lambda_l2': 6.938856929388241}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:32:08,917] Trial 26 finished with value: 0.7173333333333333 and parameters: {'n_estimators': 645, 'num_leaves': 156, 'learning_rate': 0.014899490882966673, 'min_data_in_leaf': 47, 'feature_fraction': 0.7698527915317614, 'bagging_fraction': 0.765920257742832, 'bagging_freq': 6, 'lambda_l1': 9.070305208510133, 'lambda_l2': 4.484768926525513}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:32:16,836] Trial 27 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 661, 'num_leaves': 155, 'learning_rate': 0.06418568934760312, 'min_data_in_leaf': 35, 'feature_fraction': 0.767229938070892, 'bagging_fraction': 0.765227868348847, 'bagging_freq': 4, 'lambda_l1': 8.625935772024695, 'lambda_l2': 4.477886503872022}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:32:30,778] Trial 28 finished with value: 0.7180000000000001 and parameters: {'n_estimators': 936, 'num_leaves': 75, 'learning_rate': 0.017408969056102487, 'min_data_in_leaf': 42, 'feature_fraction': 0.8759445903646313, 'bagging_fraction': 0.7979651239736779, 'bagging_freq': 3, 'lambda_l1': 9.099054479023373, 'lambda_l2': 2.852434369554882}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:32:45,083] Trial 29 finished with value: 0.7053333333333334 and parameters: {'n_estimators': 923, 'num_leaves': 56, 'learning_rate': 0.030641828367587484, 'min_data_in_leaf': 43, 'feature_fraction': 0.8664107817664328, 'bagging_fraction': 0.7238476460663682, 'bagging_freq': 3, 'lambda_l1': 7.184659052784219, 'lambda_l2': 0.36662501867873853}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:33:00,203] Trial 30 finished with value: 0.716 and parameters: {'n_estimators': 948, 'num_leaves': 78, 'learning_rate': 0.01800444541349777, 'min_data_in_leaf': 40, 'feature_fraction': 0.9338377755229452, 'bagging_fraction': 0.8047211130720192, 'bagging_freq': 3, 'lambda_l1': 9.337139903620953, 'lambda_l2': 2.3310280270204573}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:33:10,707] Trial 31 finished with value: 0.7086666666666667 and parameters: {'n_estimators': 840, 'num_leaves': 113, 'learning_rate': 0.03127840904570065, 'min_data_in_leaf': 47, 'feature_fraction': 0.8303023912502088, 'bagging_fraction': 0.8001205381531125, 'bagging_freq': 6, 'lambda_l1': 9.238741053939833, 'lambda_l2': 2.812988527824102}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:33:23,311] Trial 32 finished with value: 0.7186666666666667 and parameters: {'n_estimators': 737, 'num_leaves': 55, 'learning_rate': 0.015568455511772602, 'min_data_in_leaf': 47, 'feature_fraction': 0.8945353680665417, 'bagging_fraction': 0.7582313853130154, 'bagging_freq': 3, 'lambda_l1': 8.411394429664398, 'lambda_l2': 4.2926655874159065}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:33:31,698] Trial 33 finished with value: 0.712 and parameters: {'n_estimators': 751, 'num_leaves': 53, 'learning_rate': 0.05433012358372308, 'min_data_in_leaf': 43, 'feature_fraction': 0.9025497658410673, 'bagging_fraction': 0.8584374741468385, 'bagging_freq': 3, 'lambda_l1': 8.146093492578464, 'lambda_l2': 6.388294998669742}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:33:48,277] Trial 34 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 997, 'num_leaves': 66, 'learning_rate': 0.02622254380411942, 'min_data_in_leaf': 35, 'feature_fraction': 0.9747568333126043, 'bagging_fraction': 0.8859392806407003, 'bagging_freq': 2, 'lambda_l1': 8.505587680036859, 'lambda_l2': 5.432161574796387}. Best is trial 21 with value: 0.7193333333333334.
# [I 2025-11-16 08:34:00,044] Trial 35 finished with value: 0.72 and parameters: {'n_estimators': 902, 'num_leaves': 32, 'learning_rate': 0.018955206888115767, 'min_data_in_leaf': 48, 'feature_fraction': 0.8688034252331164, 'bagging_fraction': 0.7545142077272025, 'bagging_freq': 4, 'lambda_l1': 9.46286771510449, 'lambda_l2': 4.121831115279618}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:34:29,092] Trial 36 finished with value: 0.706 and parameters: {'n_estimators': 898, 'num_leaves': 38, 'learning_rate': 0.01730916984551532, 'min_data_in_leaf': 31, 'feature_fraction': 0.8632466076690873, 'bagging_fraction': 0.7144507512381132, 'bagging_freq': 3, 'lambda_l1': 2.1051627334867176, 'lambda_l2': 1.007910307812157}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:34:45,148] Trial 37 finished with value: 0.716 and parameters: {'n_estimators': 859, 'num_leaves': 17, 'learning_rate': 0.011919010855685997, 'min_data_in_leaf': 46, 'feature_fraction': 0.900920698701703, 'bagging_fraction': 0.75369866200708, 'bagging_freq': 4, 'lambda_l1': 7.569622529058031, 'lambda_l2': 4.057386932448696}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:02,835] Trial 38 finished with value: 0.7113333333333334 and parameters: {'n_estimators': 940, 'num_leaves': 41, 'learning_rate': 0.00839814218578979, 'min_data_in_leaf': 39, 'feature_fraction': 0.9466550802388362, 'bagging_fraction': 0.7867701848176494, 'bagging_freq': 2, 'lambda_l1': 9.0227539546996, 'lambda_l2': 2.712478115872578}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:11,318] Trial 39 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 722, 'num_leaves': 87, 'learning_rate': 0.05145793841179077, 'min_data_in_leaf': 34, 'feature_fraction': 0.8822574463249957, 'bagging_fraction': 0.9149078360344858, 'bagging_freq': 3, 'lambda_l1': 8.567760878049071, 'lambda_l2': 7.5513437475189935}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:24,522] Trial 40 finished with value: 0.7126666666666666 and parameters: {'n_estimators': 892, 'num_leaves': 27, 'learning_rate': 0.018936315522384915, 'min_data_in_leaf': 16, 'feature_fraction': 0.9588613183619658, 'bagging_fraction': 0.9997585301090318, 'bagging_freq': 4, 'lambda_l1': 9.348391315488758, 'lambda_l2': 1.8157273507986509}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:34,777] Trial 41 finished with value: 0.716 and parameters: {'n_estimators': 822, 'num_leaves': 70, 'learning_rate': 0.025753858671648876, 'min_data_in_leaf': 49, 'feature_fraction': 0.8497817352407226, 'bagging_fraction': 0.7796195299895554, 'bagging_freq': 1, 'lambda_l1': 9.986115596186982, 'lambda_l2': 4.721018034477686}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:42,541] Trial 42 finished with value: 0.7193333333333334 and parameters: {'n_estimators': 741, 'num_leaves': 51, 'learning_rate': 0.03602597709682841, 'min_data_in_leaf': 48, 'feature_fraction': 0.7915073093799408, 'bagging_fraction': 0.8073406647639012, 'bagging_freq': 3, 'lambda_l1': 9.496781785679916, 'lambda_l2': 5.84821641507908}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:35:49,380] Trial 43 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 443, 'num_leaves': 48, 'learning_rate': 0.036688354038909826, 'min_data_in_leaf': 47, 'feature_fraction': 0.9184235235751799, 'bagging_fraction': 0.739140514327493, 'bagging_freq': 3, 'lambda_l1': 9.419878455857118, 'lambda_l2': 5.781521500611403}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:36:00,673] Trial 44 finished with value: 0.6960000000000001 and parameters: {'n_estimators': 731, 'num_leaves': 28, 'learning_rate': 0.08904765601943936, 'min_data_in_leaf': 44, 'feature_fraction': 0.8831489657726281, 'bagging_fraction': 0.8020046831246157, 'bagging_freq': 4, 'lambda_l1': 5.4169111980289895, 'lambda_l2': 8.157538133617539}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:36:14,060] Trial 45 finished with value: 0.7160000000000001 and parameters: {'n_estimators': 860, 'num_leaves': 64, 'learning_rate': 0.016066737166088193, 'min_data_in_leaf': 45, 'feature_fraction': 0.7891389238739649, 'bagging_fraction': 0.8677126690424606, 'bagging_freq': 3, 'lambda_l1': 8.83863610687585, 'lambda_l2': 6.4683869192916355}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:36:21,453] Trial 46 finished with value: 0.7093333333333333 and parameters: {'n_estimators': 613, 'num_leaves': 99, 'learning_rate': 0.04601799201513101, 'min_data_in_leaf': 48, 'feature_fraction': 0.7460992466934014, 'bagging_fraction': 0.6967262015927671, 'bagging_freq': 2, 'lambda_l1': 7.558133725994876, 'lambda_l2': 4.067601427037483}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:36:44,348] Trial 47 finished with value: 0.72 and parameters: {'n_estimators': 912, 'num_leaves': 76, 'learning_rate': 0.009089726493790421, 'min_data_in_leaf': 28, 'feature_fraction': 0.8530363914673913, 'bagging_fraction': 0.8404621791983778, 'bagging_freq': 2, 'lambda_l1': 6.654889990553855, 'lambda_l2': 2.8546965135730438}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:37:02,882] Trial 48 finished with value: 0.712 and parameters: {'n_estimators': 689, 'num_leaves': 45, 'learning_rate': 0.009229084178823795, 'min_data_in_leaf': 27, 'feature_fraction': 0.8407482538142167, 'bagging_fraction': 0.8390841170994016, 'bagging_freq': 2, 'lambda_l1': 6.511313599647712, 'lambda_l2': 3.535760876747023}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:37:31,695] Trial 49 finished with value: 0.71 and parameters: {'n_estimators': 907, 'num_leaves': 29, 'learning_rate': 0.012131329332015666, 'min_data_in_leaf': 28, 'feature_fraction': 0.8527905057381402, 'bagging_fraction': 0.890989424632399, 'bagging_freq': 1, 'lambda_l1': 4.1231123946456645, 'lambda_l2': 5.918077167418206}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:37:53,399] Trial 50 finished with value: 0.712 and parameters: {'n_estimators': 865, 'num_leaves': 82, 'learning_rate': 0.005506675408140879, 'min_data_in_leaf': 24, 'feature_fraction': 0.8186724513296028, 'bagging_fraction': 0.7644664132258123, 'bagging_freq': 2, 'lambda_l1': 6.703524817555042, 'lambda_l2': 7.280293382653465}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:38:07,043] Trial 51 finished with value: 0.7080000000000001 and parameters: {'n_estimators': 961, 'num_leaves': 60, 'learning_rate': 0.03648787112416319, 'min_data_in_leaf': 20, 'feature_fraction': 0.8834167217582791, 'bagging_fraction': 0.8075967442101804, 'bagging_freq': 3, 'lambda_l1': 8.258101185566913, 'lambda_l2': 2.9683644753387086}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:38:18,590] Trial 52 finished with value: 0.7153333333333334 and parameters: {'n_estimators': 818, 'num_leaves': 74, 'learning_rate': 0.021797311330626505, 'min_data_in_leaf': 29, 'feature_fraction': 0.8319670282664022, 'bagging_fraction': 0.7880083430124745, 'bagging_freq': 2, 'lambda_l1': 9.493546516243553, 'lambda_l2': 4.12594384675426}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:38:34,224] Trial 53 finished with value: 0.7173333333333334 and parameters: {'n_estimators': 921, 'num_leaves': 229, 'learning_rate': 0.015496380312017482, 'min_data_in_leaf': 37, 'feature_fraction': 0.9237608243730537, 'bagging_fraction': 0.7499213454295464, 'bagging_freq': 1, 'lambda_l1': 8.9830975961575, 'lambda_l2': 2.213141287892431}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:38:46,024] Trial 54 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 765, 'num_leaves': 108, 'learning_rate': 0.010479284793847455, 'min_data_in_leaf': 45, 'feature_fraction': 0.7771936997013625, 'bagging_fraction': 0.8319177397970402, 'bagging_freq': 3, 'lambda_l1': 9.619178956130883, 'lambda_l2': 3.533648925742054}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:39:04,322] Trial 55 finished with value: 0.7186666666666668 and parameters: {'n_estimators': 975, 'num_leaves': 94, 'learning_rate': 0.013057287589549967, 'min_data_in_leaf': 48, 'feature_fraction': 0.8704740828332187, 'bagging_fraction': 0.9067410698166131, 'bagging_freq': 3, 'lambda_l1': 7.654749120076332, 'lambda_l2': 3.1040600736938107}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:39:20,281] Trial 56 finished with value: 0.7153333333333334 and parameters: {'n_estimators': 962, 'num_leaves': 92, 'learning_rate': 0.013429646722172804, 'min_data_in_leaf': 48, 'feature_fraction': 0.7524067397010775, 'bagging_fraction': 0.944086669204775, 'bagging_freq': 4, 'lambda_l1': 7.649506645962564, 'lambda_l2': 5.2063652072483}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:39:34,811] Trial 57 finished with value: 0.7086666666666667 and parameters: {'n_estimators': 506, 'num_leaves': 50, 'learning_rate': 0.005816377702927063, 'min_data_in_leaf': 24, 'feature_fraction': 0.8018168131851513, 'bagging_fraction': 0.9076613756870053, 'bagging_freq': 5, 'lambda_l1': 6.834755031460441, 'lambda_l2': 1.0956957582805051}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:39:53,781] Trial 58 finished with value: 0.7120000000000001 and parameters: {'n_estimators': 872, 'num_leaves': 37, 'learning_rate': 0.008270841696894128, 'min_data_in_leaf': 46, 'feature_fraction': 0.8528398854203932, 'bagging_fraction': 0.9385384020131109, 'bagging_freq': 2, 'lambda_l1': 8.291210214371468, 'lambda_l2': 3.2133768377853666}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:40:11,675] Trial 59 finished with value: 0.7093333333333334 and parameters: {'n_estimators': 840, 'num_leaves': 126, 'learning_rate': 0.0028988223934192435, 'min_data_in_leaf': 49, 'feature_fraction': 0.9105878247722723, 'bagging_fraction': 0.8700315731907095, 'bagging_freq': 4, 'lambda_l1': 7.591666532354884, 'lambda_l2': 4.7689266831635635}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:40:15,536] Trial 60 finished with value: 0.708 and parameters: {'n_estimators': 130, 'num_leaves': 93, 'learning_rate': 0.02239228308859647, 'min_data_in_leaf': 21, 'feature_fraction': 0.7400189202525834, 'bagging_fraction': 0.975657449694388, 'bagging_freq': 7, 'lambda_l1': 5.481251805580866, 'lambda_l2': 9.95038677589745}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:40:29,832] Trial 61 finished with value: 0.716 and parameters: {'n_estimators': 974, 'num_leaves': 82, 'learning_rate': 0.020012678155359225, 'min_data_in_leaf': 49, 'feature_fraction': 0.8762404018429972, 'bagging_fraction': 0.8156421675683994, 'bagging_freq': 3, 'lambda_l1': 8.760563934311712, 'lambda_l2': 2.5192380160192376}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:40:47,684] Trial 62 finished with value: 0.7146666666666668 and parameters: {'n_estimators': 921, 'num_leaves': 72, 'learning_rate': 0.012725799459714245, 'min_data_in_leaf': 43, 'feature_fraction': 0.862430942097053, 'bagging_fraction': 0.8394885492123493, 'bagging_freq': 3, 'lambda_l1': 7.948726757851154, 'lambda_l2': 3.7723293183177553}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:40:57,779] Trial 63 finished with value: 0.712 and parameters: {'n_estimators': 794, 'num_leaves': 54, 'learning_rate': 0.03226398850051573, 'min_data_in_leaf': 47, 'feature_fraction': 0.8902844631320468, 'bagging_fraction': 0.7263066624545071, 'bagging_freq': 4, 'lambda_l1': 9.649385816003111, 'lambda_l2': 1.97782940639494}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:41:12,647] Trial 64 finished with value: 0.7133333333333333 and parameters: {'n_estimators': 890, 'num_leaves': 174, 'learning_rate': 0.00952319379864433, 'min_data_in_leaf': 42, 'feature_fraction': 0.8366379318601793, 'bagging_fraction': 0.774418687101788, 'bagging_freq': 3, 'lambda_l1': 9.032254939264122, 'lambda_l2': 3.074248515854253}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:41:31,158] Trial 65 finished with value: 0.6993333333333334 and parameters: {'n_estimators': 950, 'num_leaves': 61, 'learning_rate': 0.0013677193528540104, 'min_data_in_leaf': 46, 'feature_fraction': 0.8209076762811083, 'bagging_fraction': 0.9025973531047344, 'bagging_freq': 4, 'lambda_l1': 8.467482100834257, 'lambda_l2': 4.322750282059554}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:41:51,252] Trial 66 finished with value: 0.7106666666666668 and parameters: {'n_estimators': 988, 'num_leaves': 116, 'learning_rate': 0.006404340818305746, 'min_data_in_leaf': 50, 'feature_fraction': 0.7873182939195054, 'bagging_fraction': 0.8134137922404024, 'bagging_freq': 3, 'lambda_l1': 7.086042397113404, 'lambda_l2': 3.7387529486640534}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:42:04,372] Trial 67 finished with value: 0.71 and parameters: {'n_estimators': 635, 'num_leaves': 22, 'learning_rate': 0.025249964463591616, 'min_data_in_leaf': 44, 'feature_fraction': 0.8912804644855541, 'bagging_fraction': 0.791371660156927, 'bagging_freq': 2, 'lambda_l1': 6.290529111640614, 'lambda_l2': 1.4856343335089943}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:42:09,602] Trial 68 finished with value: 0.714 and parameters: {'n_estimators': 333, 'num_leaves': 102, 'learning_rate': 0.016780699212857554, 'min_data_in_leaf': 48, 'feature_fraction': 0.8684846481794617, 'bagging_fraction': 0.7568993523692549, 'bagging_freq': 5, 'lambda_l1': 9.218436711021486, 'lambda_l2': 5.337432639580241}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:42:32,767] Trial 69 finished with value: 0.7106666666666667 and parameters: {'n_estimators': 751, 'num_leaves': 151, 'learning_rate': 0.004441857276296942, 'min_data_in_leaf': 32, 'feature_fraction': 0.8084403830227926, 'bagging_fraction': 0.7389932581609474, 'bagging_freq': 3, 'lambda_l1': 1.5227309414869032, 'lambda_l2': 2.757133579723917}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:42:52,154] Trial 70 finished with value: 0.7106666666666667 and parameters: {'n_estimators': 823, 'num_leaves': 41, 'learning_rate': 0.011251795941553015, 'min_data_in_leaf': 10, 'feature_fraction': 0.9362950765249424, 'bagging_fraction': 0.8410072841911618, 'bagging_freq': 4, 'lambda_l1': 9.594697101812722, 'lambda_l2': 5.749709826652833}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:01,868] Trial 71 finished with value: 0.718 and parameters: {'n_estimators': 775, 'num_leaves': 175, 'learning_rate': 0.026739859643404324, 'min_data_in_leaf': 50, 'feature_fraction': 0.815195399949767, 'bagging_fraction': 0.826417283441113, 'bagging_freq': 6, 'lambda_l1': 9.898769578770217, 'lambda_l2': 5.079275502636916}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:16,167] Trial 72 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 928, 'num_leaves': 195, 'learning_rate': 0.014349429882984209, 'min_data_in_leaf': 49, 'feature_fraction': 0.7956061114961447, 'bagging_fraction': 0.8543138307921438, 'bagging_freq': 5, 'lambda_l1': 8.821962014651465, 'lambda_l2': 6.562988075561313}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:27,200] Trial 73 finished with value: 0.7173333333333334 and parameters: {'n_estimators': 791, 'num_leaves': 202, 'learning_rate': 0.023467508939253798, 'min_data_in_leaf': 48, 'feature_fraction': 0.8579464472266385, 'bagging_fraction': 0.7740598757469799, 'bagging_freq': 6, 'lambda_l1': 9.72123231325812, 'lambda_l2': 6.129661786484339}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:37,830] Trial 74 finished with value: 0.7166666666666667 and parameters: {'n_estimators': 704, 'num_leaves': 227, 'learning_rate': 0.019076973195432903, 'min_data_in_leaf': 45, 'feature_fraction': 0.8399459653450245, 'bagging_fraction': 0.796417343697512, 'bagging_freq': 7, 'lambda_l1': 9.247551810344259, 'lambda_l2': 4.475842660247159}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:48,811] Trial 75 finished with value: 0.7146666666666668 and parameters: {'n_estimators': 842, 'num_leaves': 132, 'learning_rate': 0.02852547111394247, 'min_data_in_leaf': 46, 'feature_fraction': 0.9122206075134267, 'bagging_fraction': 0.8724461652511349, 'bagging_freq': 3, 'lambda_l1': 9.995445870072716, 'lambda_l2': 4.784306131191544}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:43:59,132] Trial 76 finished with value: 0.71 and parameters: {'n_estimators': 740, 'num_leaves': 181, 'learning_rate': 0.0370559208842951, 'min_data_in_leaf': 50, 'feature_fraction': 0.8737366250025808, 'bagging_fraction': 0.8171346873353811, 'bagging_freq': 5, 'lambda_l1': 8.400552646446696, 'lambda_l2': 3.3015595289716955}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:44:09,656] Trial 77 finished with value: 0.7046666666666668 and parameters: {'n_estimators': 794, 'num_leaves': 77, 'learning_rate': 0.056881047007450954, 'min_data_in_leaf': 41, 'feature_fraction': 0.7751144748477894, 'bagging_fraction': 0.781250483619993, 'bagging_freq': 2, 'lambda_l1': 7.84127562858496, 'lambda_l2': 5.651627349434541}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:44:40,529] Trial 78 finished with value: 0.69 and parameters: {'n_estimators': 882, 'num_leaves': 65, 'learning_rate': 0.03340263370741081, 'min_data_in_leaf': 47, 'feature_fraction': 0.827082319526042, 'bagging_fraction': 0.8605202897580112, 'bagging_freq': 3, 'lambda_l1': 0.15536155438369548, 'lambda_l2': 4.169491512620896}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:44:47,307] Trial 79 finished with value: 0.712 and parameters: {'n_estimators': 668, 'num_leaves': 34, 'learning_rate': 0.045471231338705946, 'min_data_in_leaf': 26, 'feature_fraction': 0.8055427396801068, 'bagging_fraction': 0.9288573110159104, 'bagging_freq': 4, 'lambda_l1': 8.712703353125171, 'lambda_l2': 4.980824840032284}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:45:08,771] Trial 80 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 910, 'num_leaves': 165, 'learning_rate': 0.007729490587986357, 'min_data_in_leaf': 13, 'feature_fraction': 0.8920255433679964, 'bagging_fraction': 0.7650551724257605, 'bagging_freq': 6, 'lambda_l1': 9.429768025620866, 'lambda_l2': 6.7086244402618975}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:45:18,154] Trial 81 finished with value: 0.7140000000000001 and parameters: {'n_estimators': 773, 'num_leaves': 184, 'learning_rate': 0.02905557700686844, 'min_data_in_leaf': 50, 'feature_fraction': 0.8203300202211802, 'bagging_fraction': 0.8282878194700102, 'bagging_freq': 6, 'lambda_l1': 9.90122049969319, 'lambda_l2': 5.121857535482337}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:45:30,117] Trial 82 finished with value: 0.7140000000000001 and parameters: {'n_estimators': 997, 'num_leaves': 174, 'learning_rate': 0.025648970124276388, 'min_data_in_leaf': 50, 'feature_fraction': 0.815391542961919, 'bagging_fraction': 0.8061639778988301, 'bagging_freq': 6, 'lambda_l1': 9.150199440025125, 'lambda_l2': 4.65799360227398}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:45:40,495] Trial 83 finished with value: 0.7146666666666667 and parameters: {'n_estimators': 695, 'num_leaves': 176, 'learning_rate': 0.01724066403689925, 'min_data_in_leaf': 48, 'feature_fraction': 0.8498911550658461, 'bagging_fraction': 0.8219701566462744, 'bagging_freq': 6, 'lambda_l1': 9.676851442899592, 'lambda_l2': 5.3989763991770365}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:45:51,109] Trial 84 finished with value: 0.718 and parameters: {'n_estimators': 724, 'num_leaves': 142, 'learning_rate': 0.02018083496367049, 'min_data_in_leaf': 49, 'feature_fraction': 0.8447332153823109, 'bagging_fraction': 0.8470621240352955, 'bagging_freq': 7, 'lambda_l1': 9.435841917257171, 'lambda_l2': 2.539718021491627}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:03,939] Trial 85 finished with value: 0.7173333333333334 and parameters: {'n_estimators': 813, 'num_leaves': 209, 'learning_rate': 0.014011005205432718, 'min_data_in_leaf': 47, 'feature_fraction': 0.7978817538819234, 'bagging_fraction': 0.8336077530736663, 'bagging_freq': 6, 'lambda_l1': 8.990905666717335, 'lambda_l2': 3.9250503652630866}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:19,529] Trial 86 finished with value: 0.7133333333333334 and parameters: {'n_estimators': 939, 'num_leaves': 163, 'learning_rate': 0.023292732625507066, 'min_data_in_leaf': 30, 'feature_fraction': 0.7816473042364442, 'bagging_fraction': 0.7943115953198091, 'bagging_freq': 3, 'lambda_l1': 7.375318361725022, 'lambda_l2': 5.165810574501522}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:28,195] Trial 87 finished with value: 0.7173333333333333 and parameters: {'n_estimators': 570, 'num_leaves': 85, 'learning_rate': 0.02682918772727999, 'min_data_in_leaf': 45, 'feature_fraction': 0.7604417005420414, 'bagging_fraction': 0.7248721348817535, 'bagging_freq': 5, 'lambda_l1': 8.141902888510845, 'lambda_l2': 6.032359931143335}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:37,646] Trial 88 finished with value: 0.7166666666666667 and parameters: {'n_estimators': 846, 'num_leaves': 56, 'learning_rate': 0.043406910962565104, 'min_data_in_leaf': 49, 'feature_fraction': 0.8319191703687999, 'bagging_fraction': 0.8828544343234935, 'bagging_freq': 1, 'lambda_l1': 9.838791807433438, 'lambda_l2': 4.350318337492284}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:48,267] Trial 89 finished with value: 0.7126666666666667 and parameters: {'n_estimators': 871, 'num_leaves': 191, 'learning_rate': 0.03386310412400362, 'min_data_in_leaf': 44, 'feature_fraction': 0.9031714498767689, 'bagging_fraction': 0.8136040535449408, 'bagging_freq': 2, 'lambda_l1': 9.231813252417993, 'lambda_l2': 3.5521220355214664}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:46:57,257] Trial 90 finished with value: 0.7086666666666667 and parameters: {'n_estimators': 898, 'num_leaves': 97, 'learning_rate': 0.0732991917549989, 'min_data_in_leaf': 47, 'feature_fraction': 0.8741851462940644, 'bagging_fraction': 0.7137395974623496, 'bagging_freq': 3, 'lambda_l1': 8.61608897017701, 'lambda_l2': 4.9569834840248905}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:47:07,644] Trial 91 finished with value: 0.7193333333333334 and parameters: {'n_estimators': 732, 'num_leaves': 142, 'learning_rate': 0.02025715937434365, 'min_data_in_leaf': 49, 'feature_fraction': 0.8473731274495302, 'bagging_fraction': 0.8435854893278892, 'bagging_freq': 7, 'lambda_l1': 9.495792742848502, 'lambda_l2': 3.0060153017883184}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:47:19,014] Trial 92 finished with value: 0.7153333333333334 and parameters: {'n_estimators': 765, 'num_leaves': 169, 'learning_rate': 0.018301849153166898, 'min_data_in_leaf': 50, 'feature_fraction': 0.8654115349290816, 'bagging_fraction': 0.8474637623839016, 'bagging_freq': 7, 'lambda_l1': 9.582897636202155, 'lambda_l2': 3.052695254835379}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:47:30,355] Trial 93 finished with value: 0.716 and parameters: {'n_estimators': 713, 'num_leaves': 159, 'learning_rate': 0.01601771042435825, 'min_data_in_leaf': 48, 'feature_fraction': 0.8132246337974662, 'bagging_fraction': 0.8241392752679971, 'bagging_freq': 7, 'lambda_l1': 8.934535146151868, 'lambda_l2': 2.1812406745460557}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:47:56,639] Trial 94 finished with value: 0.6986666666666667 and parameters: {'n_estimators': 971, 'num_leaves': 45, 'learning_rate': 0.02089751009362974, 'min_data_in_leaf': 49, 'feature_fraction': 0.856466605876883, 'bagging_fraction': 0.8990354342567443, 'bagging_freq': 6, 'lambda_l1': 3.2929425132021937, 'lambda_l2': 9.195241991586933}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:48:08,609] Trial 95 finished with value: 0.718 and parameters: {'n_estimators': 747, 'num_leaves': 143, 'learning_rate': 0.012901211706402087, 'min_data_in_leaf': 46, 'feature_fraction': 0.845337025733996, 'bagging_fraction': 0.8044152687863751, 'bagging_freq': 7, 'lambda_l1': 9.756924879337593, 'lambda_l2': 2.578036645743322}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:48:17,031] Trial 96 finished with value: 0.7153333333333334 and parameters: {'n_estimators': 649, 'num_leaves': 59, 'learning_rate': 0.027685642125424202, 'min_data_in_leaf': 48, 'feature_fraction': 0.8839842694591749, 'bagging_fraction': 0.8661054174133546, 'bagging_freq': 6, 'lambda_l1': 9.401801600702079, 'lambda_l2': 2.9479786300055615}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:48:27,553] Trial 97 finished with value: 0.7140000000000001 and parameters: {'n_estimators': 817, 'num_leaves': 196, 'learning_rate': 0.0400985488347801, 'min_data_in_leaf': 34, 'feature_fraction': 0.8366649199867071, 'bagging_fraction': 0.8362403268818748, 'bagging_freq': 4, 'lambda_l1': 9.14700074357434, 'lambda_l2': 3.35903546932849}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:48:38,994] Trial 98 finished with value: 0.714 and parameters: {'n_estimators': 622, 'num_leaves': 67, 'learning_rate': 0.009095518253552058, 'min_data_in_leaf': 42, 'feature_fraction': 0.7909829588579582, 'bagging_fraction': 0.7467479560822612, 'bagging_freq': 5, 'lambda_l1': 8.354188250264714, 'lambda_l2': 3.6784260446683144}. Best is trial 35 with value: 0.72.
# [I 2025-11-16 08:48:54,037] Trial 99 finished with value: 0.716 and parameters: {'n_estimators': 944, 'num_leaves': 148, 'learning_rate': 0.015010659169043138, 'min_data_in_leaf': 46, 'feature_fraction': 0.8261226767837615, 'bagging_fraction': 0.877670234776398, 'bagging_freq': 3, 'lambda_l1': 8.860810066653906, 'lambda_l2': 6.304776341415643}. Best is trial 35 with value: 0.72.
#
# Best LightGBM accuracy: 0.7200
# Best parameters: {'n_estimators': 902, 'num_leaves': 32, 'learning_rate': 0.018955206888115767, 'min_data_in_leaf': 48, 'feature_fraction': 0.8688034252331164, 'bagging_fraction': 0.7545142077272025, 'bagging_freq': 4, 'lambda_l1': 9.46286771510449, 'lambda_l2': 4.121831115279618}
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# [LightGBM] [Warning] feature_fraction is set=0.8688034252331164, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8688034252331164
# [LightGBM] [Warning] lambda_l2 is set=4.121831115279618, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.121831115279618
# [LightGBM] [Warning] lambda_l1 is set=9.46286771510449, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.46286771510449
# [LightGBM] [Warning] bagging_fraction is set=0.7545142077272025, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7545142077272025
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# [LightGBM] [Warning] feature_fraction is set=0.8688034252331164, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8688034252331164
# [LightGBM] [Warning] lambda_l2 is set=4.121831115279618, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.121831115279618
# [LightGBM] [Warning] lambda_l1 is set=9.46286771510449, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.46286771510449
# [LightGBM] [Warning] bagging_fraction is set=0.7545142077272025, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7545142077272025
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000222 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4767
# [LightGBM] [Info] Number of data points in the train set: 1350, number of used features: 43
# [LightGBM] [Info] Start training from score -1.827963
# [LightGBM] [Info] Start training from score -0.774920
# [LightGBM] [Info] Start training from score -0.971490
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# [LightGBM] [Warning] feature_fraction is set=0.8688034252331164, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8688034252331164
# [LightGBM] [Warning] lambda_l2 is set=4.121831115279618, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.121831115279618
# [LightGBM] [Warning] lambda_l1 is set=9.46286771510449, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.46286771510449
# [LightGBM] [Warning] bagging_fraction is set=0.7545142077272025, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7545142077272025
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# [LightGBM] [Warning] feature_fraction is set=0.8688034252331164, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8688034252331164
# [LightGBM] [Warning] lambda_l2 is set=4.121831115279618, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.121831115279618
# [LightGBM] [Warning] lambda_l1 is set=9.46286771510449, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.46286771510449
# [LightGBM] [Warning] bagging_fraction is set=0.7545142077272025, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7545142077272025
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
#
# LightGBM CV Accuracy: 0.7193 ± 0.0315
# LightGBM F1-Macro: 0.5376
# CPU times: user 27.4 s, sys: 1.3 s, total: 28.7 s
# Wall time: 22min 24s

# %% [markdown]
# ### 4.3 CatBoost with Hyperparameter Tuning

# %%
# %%time

print("\n" + "="*80)
print("Training CatBoost with Hyperparameter Tuning")
print("="*80)

if OPTUNA_AVAILABLE:
    def objective_cat(trial):
        params = {
            'iterations': trial.suggest_int('iterations', 500, 3000),
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1, log=True),
            'l2_leaf_reg': trial.suggest_int('l2_leaf_reg', 1, 9),
            'border_count': trial.suggest_int('border_count', 32, 254),
            'random_state': RANDOM_STATE,
            'verbose': 0
        }
        
        model = CatBoostClassifier(**params)
        scores = cross_val_score(model, X, y_encoded, cv=skf, scoring='accuracy', n_jobs=-1)
        return scores.mean()
    
    study_cat = optuna.create_study(direction='maximize', study_name='catboost')
    study_cat.optimize(objective_cat, n_trials=50, show_progress_bar=True)  # Fewer trials due to longer training
    
    print(f"\nBest CatBoost accuracy: {study_cat.best_value:.4f}")
    print(f"Best parameters: {study_cat.best_params}")
    
    cat_model = CatBoostClassifier(**study_cat.best_params)
    
else:
    param_dist = {
        'iterations': [500, 1000, 2000, 3000],
        'depth': [4, 6, 8, 10],
        'learning_rate': [0.001, 0.01, 0.05, 0.1],
        'l2_leaf_reg': [1, 3, 5, 7, 9],
        'border_count': [32, 64, 128, 254]
    }
    
    cat_base = CatBoostClassifier(random_state=RANDOM_STATE, verbose=0)
    random_search = RandomizedSearchCV(cat_base, param_dist, n_iter=50, cv=5,
                                      scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
    random_search.fit(X, y_encoded)
    
    print(f"\nBest CatBoost accuracy: {random_search.best_score_:.4f}")
    print(f"Best parameters: {random_search.best_params_}")
    
    cat_model = random_search.best_estimator_

cv_results = cross_validate(cat_model, X, y_encoded, cv=skf,
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['CatBoost'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': cat_model
}

print(f"\nCatBoost CV Accuracy: {model_results['CatBoost']['cv_accuracy']:.4f} ± {model_results['CatBoost']['cv_std']:.4f}")
print(f"CatBoost F1-Macro: {model_results['CatBoost']['f1_macro']:.4f}")

# %% [markdown]
# ### 4.4 Random Forest (Deep)

# %%
# %%time

print("\n" + "="*80)
print("Training Random Forest with Hyperparameter Tuning")
print("="*80)

param_grid = {
    'n_estimators': [500, 1000, 1500],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

rf_base = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1)
random_search = RandomizedSearchCV(rf_base, param_grid, n_iter=50, cv=5,
                                  scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
random_search.fit(X, y_encoded)

print(f"\nBest Random Forest accuracy: {random_search.best_score_:.4f}")
print(f"Best parameters: {random_search.best_params_}")

rf_model = random_search.best_estimator_

cv_results = cross_validate(rf_model, X, y_encoded, cv=skf,
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['RandomForest'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': rf_model
}

print(f"\nRandom Forest CV Accuracy: {model_results['RandomForest']['cv_accuracy']:.4f} ± {model_results['RandomForest']['cv_std']:.4f}")
print(f"Random Forest F1-Macro: {model_results['RandomForest']['f1_macro']:.4f}")

# %% [markdown]
# ### 4.5 Extra Trees Classifier

# %%
# %%time

print("\n" + "="*80)
print("Training Extra Trees with Hyperparameter Tuning")
print("="*80)

param_grid = {
    'n_estimators': [500, 1000, 1500],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

et_base = ExtraTreesClassifier(random_state=RANDOM_STATE, n_jobs=-1)
random_search = RandomizedSearchCV(et_base, param_grid, n_iter=50, cv=5,
                                  scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
random_search.fit(X, y_encoded)

print(f"\nBest Extra Trees accuracy: {random_search.best_score_:.4f}")
print(f"Best parameters: {random_search.best_params_}")

et_model = random_search.best_estimator_

cv_results = cross_validate(et_model, X, y_encoded, cv=skf,
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['ExtraTrees'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': et_model
}

print(f"\nExtra Trees CV Accuracy: {model_results['ExtraTrees']['cv_accuracy']:.4f} ± {model_results['ExtraTrees']['cv_std']:.4f}")
print(f"Extra Trees F1-Macro: {model_results['ExtraTrees']['f1_macro']:.4f}")

# %% [markdown]
# ### 4.6 Neural Network (Deep)

# %%
# %%time

print("\n" + "="*80)
print("Training Neural Network with Hyperparameter Tuning")
print("="*80)

param_grid = {
    'hidden_layer_sizes': [(256, 128, 64, 32), (512, 256, 128), (1024, 512, 256)],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate_init': [0.0001, 0.001, 0.01],
    'batch_size': [32, 64, 128]
}

nn_base = MLPClassifier(max_iter=1000, early_stopping=True, random_state=RANDOM_STATE)
random_search = RandomizedSearchCV(nn_base, param_grid, n_iter=30, cv=5,
                                  scoring='accuracy', n_jobs=-1, random_state=RANDOM_STATE)
random_search.fit(X, y_encoded)

print(f"\nBest Neural Network accuracy: {random_search.best_score_:.4f}")
print(f"Best parameters: {random_search.best_params_}")

nn_model = random_search.best_estimator_

cv_results = cross_validate(nn_model, X, y_encoded, cv=skf,
                           scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['NeuralNetwork'] = {
    'cv_accuracy': cv_results['test_accuracy'].mean(),
    'cv_std': cv_results['test_accuracy'].std(),
    'f1_macro': cv_results['test_f1_macro'].mean(),
    'model': nn_model
}

print(f"\nNeural Network CV Accuracy: {model_results['NeuralNetwork']['cv_accuracy']:.4f} ± {model_results['NeuralNetwork']['cv_std']:.4f}")
print(f"Neural Network F1-Macro: {model_results['NeuralNetwork']['f1_macro']:.4f}")

# %% [markdown]
# ## 5. Base Model Comparison

# %%
# Create comparison dataframe
comparison_df = pd.DataFrame([
    {
        'Model': name,
        'CV Accuracy': f"{results['cv_accuracy']:.4f}",
        'CV Std': f"{results['cv_std']:.4f}",
        'F1-Macro': f"{results['f1_macro']:.4f}"
    }
    for name, results in model_results.items()
]).sort_values('CV Accuracy', ascending=False)

print("\n" + "="*80)
print("BASE MODEL PERFORMANCE COMPARISON")
print("="*80)
print(comparison_df.to_string(index=False))

# Visualize results
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy comparison
models = list(model_results.keys())
accuracies = [model_results[m]['cv_accuracy'] for m in models]
stds = [model_results[m]['cv_std'] for m in models]

axes[0].barh(models, accuracies, xerr=stds, capsize=5)
axes[0].set_xlabel('CV Accuracy')
axes[0].set_title('Base Model Accuracy Comparison')
axes[0].set_xlim([min(accuracies) - 0.05, max(accuracies) + 0.05])

# F1-Score comparison
f1_scores = [model_results[m]['f1_macro'] for m in models]
axes[1].barh(models, f1_scores)
axes[1].set_xlabel('F1-Macro Score')
axes[1].set_title('Base Model F1-Score Comparison')
axes[1].set_xlim([min(f1_scores) - 0.05, max(f1_scores) + 0.05])

plt.tight_layout()
plt.savefig('visualizations/base_model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nVisualization saved to: visualizations/base_model_comparison.png")

# %% [markdown]
# ## 6. Layer 2: Stacking Ensemble

# %%
# %%time

print("\n" + "="*80)
print("Building Stacked Ensemble")
print("="*80)

# Select top 5 base models
sorted_models = sorted(model_results.items(), key=lambda x: x[1]['cv_accuracy'], reverse=True)
top_5_models = sorted_models[:5]

print("\nTop 5 base models for stacking:")
for i, (name, results) in enumerate(top_5_models, 1):
    print(f"{i}. {name}: {results['cv_accuracy']:.4f}")

# Create estimators list for stacking
estimators = [(name, results['model']) for name, results in top_5_models]

# Meta-model 1: Logistic Regression
print("\n" + "-"*80)
print("Stacking with Logistic Regression Meta-Model")
print("-"*80)

stack_lr = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
    cv=5,
    n_jobs=-1
)

cv_results_lr = cross_validate(stack_lr, X, y_encoded, cv=skf,
                              scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['Stack_LogReg'] = {
    'cv_accuracy': cv_results_lr['test_accuracy'].mean(),
    'cv_std': cv_results_lr['test_accuracy'].std(),
    'f1_macro': cv_results_lr['test_f1_macro'].mean(),
    'model': stack_lr
}

print(f"Stacking (LogReg) CV Accuracy: {model_results['Stack_LogReg']['cv_accuracy']:.4f} ± {model_results['Stack_LogReg']['cv_std']:.4f}")
print(f"Stacking (LogReg) F1-Macro: {model_results['Stack_LogReg']['f1_macro']:.4f}")

# Meta-model 2: XGBoost
print("\n" + "-"*80)
print("Stacking with XGBoost Meta-Model")
print("-"*80)

stack_xgb = StackingClassifier(
    estimators=estimators,
    final_estimator=xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=RANDOM_STATE),
    cv=5,
    n_jobs=-1
)

cv_results_xgb = cross_validate(stack_xgb, X, y_encoded, cv=skf,
                               scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['Stack_XGB'] = {
    'cv_accuracy': cv_results_xgb['test_accuracy'].mean(),
    'cv_std': cv_results_xgb['test_accuracy'].std(),
    'f1_macro': cv_results_xgb['test_f1_macro'].mean(),
    'model': stack_xgb
}

print(f"Stacking (XGB) CV Accuracy: {model_results['Stack_XGB']['cv_accuracy']:.4f} ± {model_results['Stack_XGB']['cv_std']:.4f}")
print(f"Stacking (XGB) F1-Macro: {model_results['Stack_XGB']['f1_macro']:.4f}")

# %% [markdown]
# ## 7. Voting Ensemble

# %%
# %%time

print("\n" + "="*80)
print("Building Voting Ensemble")
print("="*80)

# Soft voting with top 5 models
voting_clf = VotingClassifier(
    estimators=estimators,
    voting='soft',
    n_jobs=-1
)

cv_results_vote = cross_validate(voting_clf, X, y_encoded, cv=skf,
                                scoring=['accuracy', 'f1_macro'], return_train_score=True)

model_results['Voting_Soft'] = {
    'cv_accuracy': cv_results_vote['test_accuracy'].mean(),
    'cv_std': cv_results_vote['test_accuracy'].std(),
    'f1_macro': cv_results_vote['test_f1_macro'].mean(),
    'model': voting_clf
}

print(f"Voting (Soft) CV Accuracy: {model_results['Voting_Soft']['cv_accuracy']:.4f} ± {model_results['Voting_Soft']['cv_std']:.4f}")
print(f"Voting (Soft) F1-Macro: {model_results['Voting_Soft']['f1_macro']:.4f}")

# %% [markdown]
# ## 8. Final Model Selection and Comparison

# %%
# Final comparison of all models
final_comparison_df = pd.DataFrame([
    {
        'Model': name,
        'CV Accuracy': results['cv_accuracy'],
        'CV Std': results['cv_std'],
        'F1-Macro': results['f1_macro']
    }
    for name, results in model_results.items()
]).sort_values('CV Accuracy', ascending=False)

print("\n" + "="*80)
print("FINAL MODEL PERFORMANCE COMPARISON (ALL MODELS)")
print("="*80)
print(final_comparison_df.to_string(index=False))

# Select best model
best_model_name = final_comparison_df.iloc[0]['Model']
best_model = model_results[best_model_name]['model']
best_accuracy = final_comparison_df.iloc[0]['CV Accuracy']

print(f"\n{'='*80}")
print(f"BEST MODEL: {best_model_name}")
print(f"Best CV Accuracy: {best_accuracy:.4f}")
print(f"{'='*80}")

# Visualize final comparison
plt.figure(figsize=(12, 8))
plt.barh(final_comparison_df['Model'], final_comparison_df['CV Accuracy'], 
         xerr=final_comparison_df['CV Std'], capsize=5)
plt.xlabel('CV Accuracy', fontsize=12)
plt.ylabel('Model', fontsize=12)
plt.title('Final Model Performance Comparison', fontsize=14, fontweight='bold')
plt.axvline(x=best_accuracy, color='r', linestyle='--', alpha=0.7, label=f'Best: {best_accuracy:.4f}')
plt.legend()
plt.tight_layout()
plt.savefig('visualizations/final_model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nVisualization saved to: visualizations/final_model_comparison.png")

# %% [markdown]
# ## 9. Train Final Model on Full Dataset

# %%
# %%time

print("\n" + "="*80)
print(f"Training {best_model_name} on Full Dataset")
print("="*80)

# Train on full training data
best_model.fit(X, y_encoded)

# Training predictions
train_pred = best_model.predict(X)
train_accuracy = accuracy_score(y_encoded, train_pred)

print(f"\nTraining Accuracy: {train_accuracy:.4f}")
print(f"\nClassification Report (Training):")
print(classification_report(y_encoded, train_pred, target_names=le.classes_))

# Confusion matrix
cm = confusion_matrix(y_encoded, train_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title(f'{best_model_name} - Confusion Matrix (Training)', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=12)
plt.xlabel('Predicted', fontsize=12)
plt.tight_layout()
plt.savefig('visualizations/confusion_matrix_training.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nConfusion matrix saved to: visualizations/confusion_matrix_training.png")

# %% [markdown]
# ## 10. Generate Test Predictions

# %%
# %%time

print("\n" + "="*80)
print("Generating Test Predictions")
print("="*80)

# Make predictions on test set
test_pred_encoded = best_model.predict(X_test)
test_pred = le.inverse_transform(test_pred_encoded)

# Get prediction probabilities
test_pred_proba = best_model.predict_proba(X_test)

print(f"\nTest predictions generated: {len(test_pred)}")
print(f"\nPrediction distribution:")
print(pd.Series(test_pred).value_counts())

# Create submission file
submission = pd.DataFrame({
    'id': test_ids,
    'drug_category': test_pred
})

submission_filename = f"submission_{best_model_name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
submission.to_csv(submission_filename, index=False)

print(f"\nSubmission file created: {submission_filename}")
print(f"\nFirst 10 predictions:")
print(submission.head(10))

# %% [markdown]
# ## 11. Save Models

# %%
# Create models directory
os.makedirs('models', exist_ok=True)

# Save best model
best_model_filename = f"models/best_model_{best_model_name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pkl"
joblib.dump(best_model, best_model_filename)
print(f"Best model saved: {best_model_filename}")

# Save label encoder
le_filename = "models/label_encoder.pkl"
joblib.dump(le, le_filename)
print(f"Label encoder saved: {le_filename}")

# Save all model results
results_filename = "models/model_results.pkl"
joblib.dump(model_results, results_filename)
print(f"All model results saved: {results_filename}")

# Save comparison dataframe
final_comparison_df.to_csv('models/model_comparison.csv', index=False)
print("Model comparison saved: models/model_comparison.csv")

# %% [markdown]
# ## 12. Summary and Recommendations

# %%
print("\n" + "="*80)
print("TRAINING SUMMARY")
print("="*80)

print(f"\nTotal models trained: {len(model_results)}")
print(f"\nBest performing model: {best_model_name}")
print(f"Best CV Accuracy: {best_accuracy:.4f}")
print(f"Best F1-Macro: {final_comparison_df.iloc[0]['F1-Macro']:.4f}")

print(f"\n{'='*80}")
print("TOP 5 MODELS")
print("="*80)
print(final_comparison_df.head().to_string(index=False))

print(f"\n{'='*80}")
print("RECOMMENDATIONS")
print("="*80)
print("\n1. Use the best model for final submission")
print("2. Consider ensemble of top 3-5 models for potentially better results")
print("3. Monitor for overfitting - check train vs validation gap")
print("4. If time permits, run additional Bayesian optimization trials")
print("5. Consider feature engineering if accuracy needs improvement")

print(f"\n{'='*80}")
print("FILES GENERATED")
print("="*80)
print(f"1. Submission: {submission_filename}")
print(f"2. Best model: {best_model_filename}")
print(f"3. Label encoder: {le_filename}")
print(f"4. Model results: {results_filename}")
print("5. Visualizations: visualizations/")
print("6. Model comparison: models/model_comparison.csv")

print(f"\n{'='*80}")
print("TRAINING COMPLETE!")
print("="*80)
